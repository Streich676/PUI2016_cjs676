# %% [markdown]
# ### First we set up the notebook and import our tools.  I will run this book on kernal PUI2016_Python3

# %%
from __future__ import print_function, division
import geopandas as gp
import pandas as pd
import pylab as pl
import os
import json
import seaborn as sns
import matplotlib as plt
import numpy as np
import sys

#s = json.load( open(os.getenv('PUI2016')+'/fbb_matplotlibrc.json') )
#pl.rcParams.update(s)
if os.getenv("PUIDATA") is None:
    print ("$PUIDATA to point to set PUIdata dir")

# %pylab inline
print(os.getenv("PUIDATA"))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/cusp/cjs676/PUIdata
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# Below is the function which will get and move the citibike data

# %%
#check if the env variable PUIDATA exists
if os.getenv("PUIDATA") is None:
    print ("must set PUIDATA env variable")
    sys.exit()

def getCitiBikeCSV(datestring):
    '''Downloads citibike data and unzips it. If the data is downloaded by not unzippeds it zips it. Moves the data to $PUIDATA
    Arguments:
        date string as yyyymm
    '''
    print ("Downloading", datestring)
    ### First I will heck that it is not already there
    if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
        if os.path.isfile(datestring + "-citibike-tripdata.csv"):
            # if in the current dir just move it
            if os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA")):
                print ("Error moving file!, Please check!")
        #otherwise start looking for the zip file
        else:
            if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip"):
                if not os.path.isfile(datestring + "-citibike-tripdata.zip"):
                    os.system("curl -O https://s3.amazonaws.com/tripdata/" + datestring + "-citibike-tripdata.zip")
                ###  To move it I use the os.system() functions to run bash commands with arguments
                os.system("mv " + datestring + "-citibike-tripdata.zip " + os.getenv("PUIDATA"))
            ### unzip the csv 
            os.system("unzip " + os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip")
            ## NOTE: old csv citibike data had a different name structure. 
            if '2014' in datestring:
                os.system("mv " + datestring[:4] + '-' +  datestring[4:] + 
                          "\ -\ Citi\ Bike\ trip\ data.csv " + datestring + "-citibike-tripdata.csv")
            os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA"))
    ### One final check:
    if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
        print ("WARNING!!! something is wrong: the file is not there!")

    else:
        print ("file in place, you can continue")

# %% [markdown]
# Now we will get the data 201506 first #edit:  success, checked with the Terminal

# %%
datestring = '201506'
getCitiBikeCSV(datestring)
# Out:
# Downloading 201506
# file in place, you can continue

# %% [markdown]
# ###### Now we will get the 201601 data #edit success, checked with the Terminal

# %%
datestring = '201601'
getCitiBikeCSV(datestring)
# Out:
# Downloading 201601
# file in place, you can continue

# %% [markdown]
# Now we will load the citibike data into datframes
# cb15 = 201506 data
# cb16 = 201601 data

# %%
cb15 = pd.read_csv((os.getenv("PUIDATA") + "/" + '201506' + "-citibike-tripdata.csv"))

#The line line was to test if the path was proper. It is now commented out
#print((os.getenv("PUIDATA") + "/" + '201506' + "-citibike-tripdata.csv"))

# %%
#Check to see if the file was read
cb15.head(5)
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# 2               -74.000271             388         W 26 St & 10 Ave
# 3               -73.991908             531   Forsyth St & Broome St
# 4               -73.992005             532          S 5 Pl & S 4 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.759291             -73.988597   20721  Subscriber
# 1             40.722055             -73.989111   21606  Subscriber
# 2             40.749718             -74.002950   16595  Subscriber
# 3             40.718939             -73.992663   16949  Subscriber
# 4             40.710451             -73.960876   17028    Customer
#
#    birth year  gender
# 0      1984.0       1
# 1      1997.0       1
# 2      1993.0       1
# 3      1981.0       1
# 4         NaN       0

# %% [markdown]
# Repeating the process for the next file.

# %%
cb16 = pd.read_csv((os.getenv("PUIDATA") + "/" + '201601' + "-citibike-tripdata.csv"))

#The line line was to test if the path was proper. It is now commented out
#print((os.getenv("PUIDATA") + "/" + '201601' + "-citibike-tripdata.csv"))

# %%
cb16.head(5)
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           923  1/1/2016 00:00:41  1/1/2016 00:16:04               268
# 1           379  1/1/2016 00:00:45  1/1/2016 00:07:04               476
# 2           589  1/1/2016 00:00:48  1/1/2016 00:10:37               489
# 3           889  1/1/2016 00:01:06  1/1/2016 00:15:56               268
# 4          1480  1/1/2016 00:01:12  1/1/2016 00:25:52              2006
#
#        start station name  start station latitude  start station longitude  \
# 0   Howard St & Centre St               40.719105               -73.999733
# 1         E 31 St & 3 Ave               40.743943               -73.979661
# 2        10 Ave & W 28 St               40.750664               -74.001768
# 3   Howard St & Centre St               40.719105               -73.999733
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
#    end station id            end station name  end station latitude  \
# 0            3002  South End Ave & Liberty St             40.711512
# 1             498          Broadway & W 32 St             40.748549
# 2             284       Greenwich Ave & 8 Ave             40.739017
# 3            3002  South End Ave & Liberty St             40.711512
# 4            2006      Central Park S & 6 Ave             40.765909
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -74.015756   22285  Subscriber      1958.0       1
# 1             -73.988084   17827  Subscriber      1969.0       1
# 2             -74.002638   21997  Subscriber      1982.0       2
# 3             -74.015756   22794  Subscriber      1961.0       2
# 4             -73.976342   14562  Subscriber      1952.0       1

# %% [markdown]
# #Success.
# Now to try to get the IRS data.
# From investigation on the IRS page: File 14zp33ny.xls = https://www.irs.gov/pub/irs-soi/14zp33ny.xls

# %% [markdown]
# #First attempt.  Trying to use the hint =on the midterm = ver1. I didnt know where the file was exactly
#
# This time I will use curl and move it
#
# #datestring = '201601'
# #getCitiBikeCSV(datestring)
#
# def readIncomeXls(url):
#     return pd.read_excel(url, header=3, index_col="ZIP\ncode [1]")

# %%
#url = https://www.irs.gov/pub/irs-soi/14zp33ny.xls
os.system('curl -O https://www.irs.gov/pub/irs-soi/14zp33ny.xls')
# Out:
# 0

# %%
mv 14zp33ny.xls $PUIDATA
# Out:
# mv: setting attribute `security.selinux' for `security.selinux': Permission denied

# %%
irs = pd.read_excel((os.getenv("PUIDATA") + "/" + '14zp33ny.xls'), header=3, index_col="ZIP\ncode [1]")
#14zp33ny.xls

#print(os.getenv("PUIDATA") + "/" + '14zp33ny.xls')

# %% [markdown]
# Check to see if the file was aquired

# %%
irs.head(5)
# Out:
#               Size of adjusted gross income  Number of returns  \
# ZIP\ncode [1]
# NaN                                     NaN                NaN
# NaN                                     NaN               -1.0
# 0                                     Total          9397410.0
# 0                          $1 under $25,000          3617400.0
# 0                     $25,000 under $50,000          2070870.0
#
#                Number of single returns  Number of joint returns  \
# ZIP\ncode [1]
# NaN                                 NaN                      NaN
# NaN                                -2.0                     -3.0
# 0                             4750550.0                2942890.0
# 0                             2432240.0                 468500.0
# 0                             1103290.0                 449390.0
#
#                Number of head of household returns  \
# ZIP\ncode [1]
# NaN                                            NaN
# NaN                                           -4.0
# 0                                        1515950.0
# 0                                         665410.0
# 0                                         467540.0
#
#                Number with paid preparer's signature  Number of exemptions  \
# ZIP\ncode [1]
# NaN                                              NaN                   NaN
# NaN                                             -5.0                  -6.0
# 0                                          6110600.0            17322490.0
# 0                                          2247810.0             5220510.0
# 0                                          1280840.0             3729240.0
#
#                Number of dependents Number of volunteer prepared returns [2]  \
# ZIP\ncode [1]
# NaN                             NaN                                    Total
# NaN                            -7.0                                       -8
# 0                         5539120.0                                   279510
# 0                         1678560.0                                   187260
# 0                         1219770.0                                    69390
#
#                                                      Unnamed: 10     ...       \
# ZIP\ncode [1]                                                        ...
# NaN            Number of volunteer income tax assistance (VIT...     ...
# NaN                                                           -9     ...
# 0                                                         197150     ...
# 0                                                         136800     ...
# 0                                                          49620     ...
#
#               Total tax liability [9]  Unnamed: 116 Additional Medicare tax  \
# ZIP\ncode [1]
# NaN                 Number of returns        Amount       Number of returns
# NaN                              -114          -115                    -116
# 0                             7229610     129761061                  280780
# 0                             1804270       1677200                       0
# 0                             1769800       4790944                       0
#
#               Unnamed: 118 Net investment income tax Unnamed: 120  \
# ZIP\ncode [1]
# NaN                 Amount         Number of returns       Amount
# NaN                   -117                      -118         -119
# 0                   900175                    300410      2745701
# 0                        0                         0            0
# 0                        0                         0            0
#
#               Tax due at time of filing [10] Unnamed: 122  \
# ZIP\ncode [1]
# NaN                        Number of returns       Amount
# NaN                                     -120         -121
# 0                                    1781540     10177242
# 0                                     451080       361017
# 0                                     287080       461908
#
#               Overpayments refunded [11] Unnamed: 124
# ZIP\ncode [1]
# NaN                    Number of returns       Amount
# NaN                                 -122         -123
# 0                                7115810     25052463
# 0                                2886740      6049923
# 0                                1747120      4510472
#
# [5 rows x 124 columns]

# %%
#reset the index so that I can use the zipcode column
irs = irs.reset_index()

# %%
irs.columns
# Out:
# Index(['ZIP\ncode [1]', 'Size of adjusted gross income', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents', 'Number of volunteer prepared returns [2]',
#        ...
#        'Total tax liability [9]', 'Unnamed: 116', 'Additional Medicare tax',
#        'Unnamed: 118', 'Net investment income tax', 'Unnamed: 120',
#        'Tax due at time of filing [10]', 'Unnamed: 122',
#        'Overpayments refunded [11]', 'Unnamed: 124'],
#       dtype='object', length=125)

# %%
#Convert the 'Zip\ncode [1]' to a number
irs['ZIP\ncode [1]'] = pd.to_numeric(irs['ZIP\ncode [1]'], errors='coerce')
irs['ZIP\ncode [1]'] = pd.to_numeric(irs['ZIP\ncode [1]'], errors='coerce')

# %%
#check the datatype
dtype(irs['ZIP\ncode [1]'])
# Out:
# dtype('float64')

# %%
irs.head(5)
# Out:
#    ZIP\ncode [1] Size of adjusted gross income  Number of returns  \
# 0            NaN                           NaN                NaN
# 1            NaN                           NaN               -1.0
# 2            0.0                         Total          9397410.0
# 3            0.0              $1 under $25,000          3617400.0
# 4            0.0         $25,000 under $50,000          2070870.0
#
#    Number of single returns  Number of joint returns  \
# 0                       NaN                      NaN
# 1                      -2.0                     -3.0
# 2                 4750550.0                2942890.0
# 3                 2432240.0                 468500.0
# 4                 1103290.0                 449390.0
#
#    Number of head of household returns  Number with paid preparer's signature  \
# 0                                  NaN                                    NaN
# 1                                 -4.0                                   -5.0
# 2                            1515950.0                              6110600.0
# 3                             665410.0                              2247810.0
# 4                             467540.0                              1280840.0
#
#    Number of exemptions  Number of dependents  \
# 0                   NaN                   NaN
# 1                  -6.0                  -7.0
# 2            17322490.0             5539120.0
# 3             5220510.0             1678560.0
# 4             3729240.0             1219770.0
#
#   Number of volunteer prepared returns [2]     ...       \
# 0                                    Total     ...
# 1                                       -8     ...
# 2                                   279510     ...
# 3                                   187260     ...
# 4                                    69390     ...
#
#   Total tax liability [9] Unnamed: 116  Additional Medicare tax Unnamed: 118  \
# 0       Number of returns       Amount        Number of returns       Amount
# 1                    -114         -115                     -116         -117
# 2                 7229610    129761061                   280780       900175
# 3                 1804270      1677200                        0            0
# 4                 1769800      4790944                        0            0
#
#   Net investment income tax Unnamed: 120 Tax due at time of filing [10]  \
# 0         Number of returns       Amount              Number of returns
# 1                      -118         -119                           -120
# 2                    300410      2745701                        1781540
# 3                         0            0                         451080
# 4                         0            0                         287080
#
#   Unnamed: 122 Overpayments refunded [11] Unnamed: 124
# 0       Amount          Number of returns       Amount
# 1         -121                       -122         -123
# 2     10177242                    7115810     25052463
# 3       361017                    2886740      6049923
# 4       461908                    1747120      4510472
#
# [5 rows x 125 columns]

# %%
irs.columns
# Out:
# Index(['ZIP\ncode [1]', 'Size of adjusted gross income', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents', 'Number of volunteer prepared returns [2]',
#        ...
#        'Total tax liability [9]', 'Unnamed: 116', 'Additional Medicare tax',
#        'Unnamed: 118', 'Net investment income tax', 'Unnamed: 120',
#        'Tax due at time of filing [10]', 'Unnamed: 122',
#        'Overpayments refunded [11]', 'Unnamed: 124'],
#       dtype='object', length=125)

# %%
#"Adjusted gross income (AGI) [3]"
dtype(irs["Adjusted gross income (AGI) [3]"])
# Out:
# dtype('float64')

# %%
dtype(irs['Number of returns'])
# Out:
# dtype('float64')

# %%
#MAKE THE NEW DATAFRAME .zipincome
#	zipcodes	income	N	Njoint	Ndeps	incomePC
irs.head(5)
# Out:
#    ZIP\ncode [1] Size of adjusted gross income  Number of returns  \
# 0            NaN                           NaN                NaN
# 1            NaN                           NaN               -1.0
# 2            0.0                         Total          9397410.0
# 3            0.0              $1 under $25,000          3617400.0
# 4            0.0         $25,000 under $50,000          2070870.0
#
#    Number of single returns  Number of joint returns  \
# 0                       NaN                      NaN
# 1                      -2.0                     -3.0
# 2                 4750550.0                2942890.0
# 3                 2432240.0                 468500.0
# 4                 1103290.0                 449390.0
#
#    Number of head of household returns  Number with paid preparer's signature  \
# 0                                  NaN                                    NaN
# 1                                 -4.0                                   -5.0
# 2                            1515950.0                              6110600.0
# 3                             665410.0                              2247810.0
# 4                             467540.0                              1280840.0
#
#    Number of exemptions  Number of dependents  \
# 0                   NaN                   NaN
# 1                  -6.0                  -7.0
# 2            17322490.0             5539120.0
# 3             5220510.0             1678560.0
# 4             3729240.0             1219770.0
#
#   Number of volunteer prepared returns [2]     ...       \
# 0                                    Total     ...
# 1                                       -8     ...
# 2                                   279510     ...
# 3                                   187260     ...
# 4                                    69390     ...
#
#   Total tax liability [9] Unnamed: 116  Additional Medicare tax Unnamed: 118  \
# 0       Number of returns       Amount        Number of returns       Amount
# 1                    -114         -115                     -116         -117
# 2                 7229610    129761061                   280780       900175
# 3                 1804270      1677200                        0            0
# 4                 1769800      4790944                        0            0
#
#   Net investment income tax Unnamed: 120 Tax due at time of filing [10]  \
# 0         Number of returns       Amount              Number of returns
# 1                      -118         -119                           -120
# 2                    300410      2745701                        1781540
# 3                         0            0                         451080
# 4                         0            0                         287080
#
#   Unnamed: 122 Overpayments refunded [11] Unnamed: 124
# 0       Amount          Number of returns       Amount
# 1         -121                       -122         -123
# 2     10177242                    7115810     25052463
# 3       361017                    2886740      6049923
# 4       461908                    1747120      4510472
#
# [5 rows x 125 columns]

# %%
#df['Col3'] = (df['Col2'] <= 1).astype(int)
#
irs['incomePC'] = ((irs['Adjusted gross income (AGI) [3]']) / (irs['Number of returns'] + irs['Number of dependents'] + irs['Number of joint returns']))

# %%
#MAKE THE NEW DATAFRAME .zipincome
#	zipcodes	income	N	Njoint	Ndeps	incomePC
zipincome = irs[['ZIP\ncode [1]','Adjusted gross income (AGI) [3]','Number of returns', 'Number of joint returns', 'Number of dependents', 'incomePC']]

# %%
zipincome.head(5)
# Out:
#    ZIP\ncode [1]  Adjusted gross income (AGI) [3]  Number of returns  \
# 0            NaN                              NaN                NaN
# 1            NaN                            -11.0               -1.0
# 2            0.0                      766646080.0          9397410.0
# 3            0.0                       43301874.0          3617400.0
# 4            0.0                       75271045.0          2070870.0
#
#    Number of joint returns  Number of dependents   incomePC
# 0                      NaN                   NaN        NaN
# 1                     -3.0                  -7.0   1.000000
# 2                2942890.0             5539120.0  42.878688
# 3                 468500.0             1678560.0   7.511870
# 4                 449390.0             1219770.0  20.125786

# %%
#Rename the columns
#zipcodes	income	N	Njoint	Ndeps	incomePC
#df=df.rename(columns = {'two':'new_name'})
zipincome = zipincome.rename(columns = {'ZIP\ncode [1]': 'zipcodes','Adjusted gross income (AGI) [3]':'income', 'Number of joint returns': 'Njoint', 
                                       'Number of dependents': 'Ndeps'})

# %%
zipincome.head(5)
# Out:
#    zipcodes       income  Number of returns     Njoint      Ndeps   incomePC
# 0       NaN          NaN                NaN        NaN        NaN        NaN
# 1       NaN        -11.0               -1.0       -3.0       -7.0   1.000000
# 2       0.0  766646080.0          9397410.0  2942890.0  5539120.0  42.878688
# 3       0.0   43301874.0          3617400.0   468500.0  1678560.0   7.511870
# 4       0.0   75271045.0          2070870.0   449390.0  1219770.0  20.125786

# %%
#Remove Nan values 
zipincome.dropna(subset=['zipcodes'])
# Out:
#        zipcodes       income  Number of returns     Njoint      Ndeps  \
# 2           0.0  766646080.0          9397410.0  2942890.0  5539120.0
# 3           0.0   43301874.0          3617400.0   468500.0  1678560.0
# 4           0.0   75271045.0          2070870.0   449390.0  1219770.0
# 5           0.0   76727346.0          1248170.0   417090.0   690410.0
# 6           0.0   69807714.0           805170.0   408350.0   509330.0
# 7           0.0  160015013.0          1171760.0   818600.0   963610.0
# 8           0.0  341523088.0           484040.0   380960.0   477440.0
# 10      10001.0    2363960.0            14080.0     2410.0     3250.0
# 11      10001.0      44778.0             3880.0      350.0      930.0
# 12      10001.0      93575.0             2530.0      250.0      680.0
# 13      10001.0     114745.0             1850.0      190.0      330.0
# 14      10001.0     112658.0             1300.0      170.0      200.0
# 15      10001.0     329084.0             2350.0      530.0      410.0
# 16      10001.0    1669120.0             2170.0      920.0      700.0
# 18      10002.0    2215542.0            43370.0    11040.0    19160.0
# 19      10002.0     267152.0            23350.0     6160.0    10300.0
# 20      10002.0     298008.0             8270.0     1860.0     4550.0
# 21      10002.0     275474.0             4500.0      660.0     1530.0
# 22      10002.0     216709.0             2510.0      510.0      870.0
# 23      10002.0     436247.0             3200.0     1090.0     1140.0
# 24      10002.0     721952.0             1540.0      760.0      770.0
# 26      10003.0    6910992.0            29810.0     5460.0     4790.0
# 8            550  6/1/2015 0:07  6/1/2015 0:16               525
# 9            545  6/1/2015 0:08  6/1/2015 0:17               403
# 10           752  6/1/2015 0:08  6/1/2015 0:21               441
# 11          1743  6/1/2015 0:08  6/1/2015 0:37               329
# 12           964  6/1/2015 0:10  6/1/2015 0:27               505
# 13           207  6/1/2015 0:11  6/1/2015 0:14               294
# 14           511  6/1/2015 0:13  6/1/2015 0:21               257
#
#             start station name  start station latitude  \
# 0     MacDougal St & Prince St               40.727103
# 1          St Marks Pl & 1 Ave               40.727791
# 2   Greenwich Ave & Charles St               40.735238
# 3         Allen St & Hester St               40.716059
# 4      University Pl & E 14 St               40.734927
# 5        Greenwich Ave & 8 Ave               40.739017
# 6          Bank St & Hudson St               40.736529
# 7              W 29 St & 9 Ave               40.750073
# 8             W 34 St & 11 Ave               40.755942
# 9               E 2 St & 2 Ave               40.725029
# 10             E 52 St & 2 Ave               40.756014
# 11   Greenwich St & N Moore St               40.720434
# 12             6 Ave & W 33 St               40.749013
# 13         Washington Square E               40.730494
# 14     Lispenard St & Broadway               40.719392
#
#     start station longitude  end station id          end station name  \
# 0                -74.002971            2021           W 45 St & 8 Ave
# 1                -73.985649             312   Allen St & E Houston St
# 2                -74.000271             388          W 26 St & 10 Ave
# 3                -73.991908             531    Forsyth St & Broome St
# 4                -73.992005             532           S 5 Pl & S 4 St
# 5                -74.002638             410   Suffolk St & Stanton St
# 6                -74.006180            2003           1 Ave & E 18 St
# 7                -73.998393             445        E 10 St & Avenue A
# 8                -74.002116             447           8 Ave & W 52 St
# 9                -73.990697             439            E 4 St & 2 Ave
# 10               -73.967416             492           W 33 St & 7 Ave
# 11               -74.010206             147  Greenwich St & Warren St
# 12               -73.988484             377          6 Ave & Canal St
# 13               -73.995721             439            E 4 St & 2 Ave
# 14               -74.002472             408     Market St & Cherry St
#
#     end station latitude  end station longitude  bikeid    usertype  \
# 0              40.759291             -73.988597   20721  Subscriber
# 1              40.722055             -73.989111   21606  Subscriber
# 2              40.749718             -74.002950   16595  Subscriber
# 3              40.718939             -73.992663   16949  Subscriber
# 4              40.710451             -73.960876   17028    Customer
# 5              40.720664             -73.985180   20857  Subscriber
# 6              40.733812             -73.980544   15978  Subscriber
# 7              40.727408             -73.981420   17306  Subscriber
# 8              40.763707             -73.985162   18392  Subscriber
# 9              40.726281             -73.989780   16300  Subscriber
# 10             40.750200             -73.990931   16874  Subscriber
# 11             40.715422             -74.011220   14726  Subscriber
# 12             40.722438             -74.005664   18699  Subscriber
# 13             40.726281             -73.989780   17390  Subscriber
# 14             40.710762             -73.994004   14777  Subscriber
#
#     birth year  gender
# 0       1984.0       1
# 1       1997.0       1
# 2       1993.0       1
# 3       1981.0       1
# 4          NaN       0
# 5       1976.0       1
# 6       1976.0       1
# 7       1962.0       2
# 8       1973.0       1
# 9       1958.0       1
# 10      1964.0       1
# 11      1982.0       2
# 12      1985.0       2
# 13      1989.0       1
# 14      1983.0       2

# %%
import json
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib


def get_jsonparsed_data(url):
    """
    from http://stackoverflow.com/questions/12965203/how-to-get-json-from-webpage-into-python-script
    Receive the content of ``url``, parse it as JSON and return the object.
    Parameters
    ----------
    url : str
    Returns
    -------
    dict
    """
    response = urllib.urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
##Get the 15 data
#Now i have this data. I dont know how to merge it with the dataframe. 


cb15statloc = (get_jsonparsed_data('http://cosmo.nyu.edu/~fb55/UI_CUSP_2015/data/stationsZips2015.json'))

# %%
zipincome3 = pd.read_json('http://cosmo.nyu.edu/~fb55/UI_CUSP_2015/data/stationsZips2015.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-24b83da02a55> in <module>()
# ----> 1 zipincome3 = pd.read_json('http://cosmo.nyu.edu/~fb55/UI_CUSP_2015/data/stationsZips2015.json')
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/io/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     209         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     210                           keep_default_dates, numpy, precise_float,
# --> 211                           date_unit).parse()
#     212
#     213     if typ == 'series' or obj is None:
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/io/json.py in parse(self)
#     277
#     278         else:
# --> 279             self._parse_no_numpy()
#     280
#     281         if self.obj is None:
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/io/json.py in _parse_no_numpy(self)
#     494         if orient == "columns":
#     495             self.obj = DataFrame(
# --> 496                 loads(json, precise_float=self.precise_float), dtype=None)
#     497         elif orient == "split":
#     498             decoded = dict((str(k), v)
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     358             arrays = [data[k] for k in keys]
#     359
# --> 360         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     361
#     362     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5229     # figure out the index, if necessary
#    5230     if index is None:
# -> 5231         index = extract_index(arrays)
#    5232     else:
#    5233         index = _ensure_index(index)
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/core/frame.py in extract_index(data)
#    5268
#    5269         if not indexes and not raw_lengths:
# -> 5270             raise ValueError('If using all scalar values, you must pass'
#    5271                              ' an index')
#    5272
#
# ValueError: If using all scalar values, you must pass an index

# %%
cb15statloc.from_dict(cb15statloc, orient='columns', dtype=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-4aa72545e04a> in <module>()
# ----> 1 cb15statloc.from_dict(cb15statloc, orient='columns', dtype=None)
#
# AttributeError: 'dict' object has no attribute 'from_dict'

# %%
pd.DataFrame([[key,value] for key,value in cb15statloc.iteritems()],columns=["key_col","val_col"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-f6b99dd7062c> in <module>()
# ----> 1 pd.DataFrame([[key,value] for key,value in cb15statloc.iteritems()],columns=["key_col","val_col"])
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
#Change it into a data frame
#This did not work really
s1 = pd.Series(cb15statloc, name='zipcodes')
s1.index.name = 'start station id'

# %%
#change into data frame
s1.reset_index()
# Out:
#     start station id  zipcodes
# 0                116     10011
# 1                119     11205
# 2                120      1476
# 3                127      2823
# 4                128      2926
# 5                137     10022
# 6                143      4701
# 7                144     11201
# 8                146      3886
# 9                147     10282
# 10               150     10009
# 11               151      4023
# 12               152     10007
# 13               153     10016
# 14               157     11201
# 15               160     10016
# 16               161     10012
# 17               164      2101
# 18               167       914
# 19               168     10011
# 20               173      6810
# 21               174      2533
# 22               195     10045
# 23              2000      1007
# 24              2001     11201
# 25              2002      3912
# 26              2003     10009
# 27              2004     10013
# 28              2005     11249
# 29              2006     10019
# ..               ...       ...
# 296              515      6323
# 297              516     10017
# 298              517     10168
# 299              518     10016
# 300              519     10168
# 301              520     10019
# 302              521      2755
# 303              522     10022
# 304              523     10018
# 305              524      7408
# 306              525     10001
# 307              526      5003
# 308              527     10016
# 309              528      6307
# 310              529     10036
# 311              530     10019
# 312              531     10002
# 313              532     11211
# 314              533     10018
# 315              534     10004
# 316              536      6525
# 317              537     10010
# 318              538     10017
# 319              539     11249
# 320              545     10010
# 321              546     10016
# 322               72     10019
# 323               79      2984
# 324               82     10038
# 325               83     11217
#
# [326 rows x 2 columns]

# %%
cb15.head(5)
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# 2               -74.000271             388         W 26 St & 10 Ave
# 3               -73.991908             531   Forsyth St & Broome St
# 4               -73.992005             532          S 5 Pl & S 4 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.759291             -73.988597   20721  Subscriber
# 1             40.722055             -73.989111   21606  Subscriber
# 2             40.749718             -74.002950   16595  Subscriber
# 3             40.718939             -73.992663   16949  Subscriber
# 4             40.710451             -73.960876   17028    Customer
#
#    birth year  gender
# 0      1984.0       1
# 1      1997.0       1
# 2      1993.0       1
# 3      1981.0       1
# 4         NaN       0

# %%
dtype(cb15['start station id'])
# Out:
# dtype('int64')

# %%
#MERGE MERGE MERGE
##on start station ID
#bblnrgdata = bsize2.merge(nrg2, how='inner', on='BBL')
cb15final = cb15.merge(s1, how='inner', on='start station id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-b1c643f50453> in <module>()
#       2 ##on start station ID
#       3 #bblnrgdata = bsize2.merge(nrg2, how='inner', on='BBL')
# ----> 4 cb15final = cb15.merge(s1, how='inner', on='start station id')
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4435                      right_on=right_on, left_index=left_index,
#    4436                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4437                      copy=copy, indicator=indicator)
#    4438
#    4439     def round(self, decimals=0, *args, **kwargs):
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/tools/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/tools/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     196             raise ValueError(
#     197                 'can not merge DataFrame with instance of '
# --> 198                 'type {0}'.format(type(right)))
#     199
#     200         # warn user when merging between different levels
#
# ValueError: can not merge DataFrame with instance of type <class 'pandas.core.series.Series'>
