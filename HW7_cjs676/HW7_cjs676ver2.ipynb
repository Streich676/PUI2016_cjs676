# %%
import pylab as pl
import pandas as pd
import numpy as np
import scipy.stats
import statsmodels.api as sm
# %pylab inline
from dateutil.parser import parse
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataframe = pd.read_csv('https://data.cityofnewyork.us/api/views/h9gi-nx95/rows.csv?accessType=DOWNLOAD')

# %%
dataframe.columns
# Out:
# Index(['DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
#        'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
#        'CONTRIBUTING FACTOR VEHICLE 5', 'UNIQUE KEY', 'VEHICLE TYPE CODE 1',
#        'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4',
#        'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
dataframe.head(3)
# Out:
#          DATE   TIME    BOROUGH  ZIP CODE  LATITUDE  LONGITUDE LOCATION  \
# 0  09/18/2016  19:09     QUEENS   11422.0       NaN        NaN      NaN
# 1  09/18/2016  19:09   BROOKLYN   11237.0       NaN        NaN      NaN
# 2  09/18/2016   1:09  MANHATTAN   10012.0       NaN        NaN      NaN
#
#     ON STREET NAME CROSS STREET NAME          OFF STREET NAME  \
# 0              NaN               NaN     234-32    131 AVENUE
# 1              NaN               NaN  140       MORGAN AVENUE
# 2  DELANCEY STREET            BOWERY                      NaN
#
#           ...           CONTRIBUTING FACTOR VEHICLE 2  \
# 0         ...                                     NaN
# 1         ...          Driver Inattention/Distraction
# 2         ...                             Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# ...

# %%
dtype(dataframe['DATE'])
# Out:
# dtype('O')

# %%
dataframe["DATE"].dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(dataframe['DATE'])
# Out:
# 2        2016-09-18
# 3        2016-09-18
# 4        2016-09-18
# 5        2016-09-18
# 6        2015-08-25
# 7        2012-07-27
# 8        2014-05-17
# 9        2016-08-12
# 10       2016-08-12
# 11       2016-08-12
# 12       2016-08-12
# 13       2016-08-12
# 14       2016-08-12
# 15       2016-09-18
# 16       2016-09-18
# 17       2016-09-18
# 18       2016-09-18
# 19       2016-08-12
# 20       2016-08-12
# 21       2016-08-12
# 22       2016-08-12
# 23       2016-05-03
# 24       2016-05-03
# 25       2016-05-03
# 26       2016-05-03
# 27       2016-09-17
# 28       2016-09-17
# 29       2016-09-17
# 30       2016-09-17
# 31       2016-09-17
#             ...
# 913773   2012-07-11
# 913774   2012-07-11
# 913775   2012-07-10
# 913776   2012-07-10
# 913777   2012-07-10
# 913778   2012-07-09
# 913779   2012-07-09
# 913780   2012-07-08
# 913781   2012-07-08
# 913782   2012-07-07
# 913783   2012-07-07
# 913784   2012-07-07
# 913785   2012-07-07
# 913786   2012-07-06
# ...

# %%
dataframe["DATE"].dtype
# Out:
# dtype('O')

# %%
dataframe.drop((dataframe['DATE'] < '10/28/2016') , axis=0, inplace=True)

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of               DATE   TIME        BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       09/18/2016   1:09      MANHATTAN   10012.0        NaN        NaN
# 3       09/18/2016   1:09            NaN       NaN  40.862498 -73.934185
# 4       09/18/2016  20:09       BROOKLYN   11229.0        NaN        NaN
# 5       09/18/2016  20:09      MANHATTAN   10003.0        NaN        NaN
# 6       08/25/2015  19:00            NaN       NaN  40.732941 -73.920382
# 7       07/27/2012  22:35            NaN       NaN        NaN        NaN
# 8       05/17/2014   0:45            NaN       NaN        NaN        NaN
# 9       08/12/2016   1:08         QUEENS   11377.0        NaN        NaN
# 10      08/12/2016  20:08          BRONX   10460.0        NaN        NaN
# 11      08/12/2016  20:08          BRONX   10466.0        NaN        NaN
# 12      08/12/2016  20:08       BROOKLYN   11216.0        NaN        NaN
# ...

# %%
#iris.ix[iris['sepal length (cm)'] >= 5]
dataframe.ix[dataframe['DATE'] <= 10/28/2016]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-feb81928238a> in <module>()
#       1 #iris.ix[iris['sepal length (cm)'] >= 5]
# ----> 2 dataframe.ix[dataframe['DATE'] <= 10/28/2016]
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     761                 other = np.asarray(other)
#     762
# --> 763             res = na_op(values, other)
#     764             if isscalar(res):
#     765                 raise TypeError('Could not compare %s type with Series' %
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     681                     result = lib.vec_compare(x, y, op)
#     682             else:
# --> 683                 result = lib.scalar_compare(x, y, op)
#     684         else:
#     685
#
# ...

# %%
dataframe.ix[ts.index.indexer_between_time(datetime.time(9), datetime.time(18))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d1a33da5047d> in <module>()
# ----> 1 ts.ix[ts.index.indexer_between_time(datetime.time(9), datetime.time(18))]
#
# NameError: name 'ts' is not defined

# %%
len(dataframe)
# Out:
# 913803

# %%
dataframe.columns
# Out:
# Index(['Rank', 'Name', 'Unit', 'Date'], dtype='object')

# %%
pd.to_datetime(dataframe['Date'])
# Out:
# 0      1865-08-24
# 1      1865-11-08
# 2      1865-12-02
# 3      1865-12-14
# 4      1866-05-21
# 5      1866-05-21
# 6      1867-08-27
# 7      1868-04-16
# 8      1869-10-06
# 9      1869-10-24
# 10     1870-12-04
# 11     1871-03-27
# 12     1872-06-29
# 13     1872-09-08
# 14     1873-02-09
# 15     1873-10-24
# 16     1874-08-16
# 17     1875-09-14
# 18     1875-09-14
# 19     1875-09-14
# 20     1876-02-08
# 21     1876-02-08
# 22     1876-02-11
# 23     1877-11-01
# 24     1878-03-14
# 25     1879-01-07
# 26     1879-01-14
# 27     1879-12-09
# 28     1880-01-01
# 29     1880-01-20
#           ...
# 1139   2001-09-11
# 1140   2001-09-11
# 1141   2001-09-11
# 1142   2001-09-11
# 1143   2001-09-11
# 1144   2001-09-11
# 1145   2001-09-11
# 1146   2001-09-11
# 1147   2001-09-11
# 1148   2001-09-11
# 1149   2001-09-11
# 1150   2001-09-11
# 1151   2002-04-18
# 1152   2003-09-27
# 1153   2003-12-16
# 1154   2004-11-29
# 1155   2005-01-23
# 1156   2005-01-23
# 1157   2005-01-23
# ...

# %%
dataframe['Date2'] = pd.to_datetime(dataframe['Date'])

# %%
dataframe.head(3)
# Out:
#           Rank                Name      Unit              Date      Date2
# 0  FIREFIGHTER  ROBERT WINTRINGHAM  ENGINE 1   AUGUST 24, 1865 1865-08-24
# 1  FIREFIGHTER         GEORGE BELL  ENGINE 8  NOVEMBER 8, 1865 1865-11-08
# 2  FIREFIGHTER        THOMAS IRVIN  ENGINE 4  DECEMBER 2, 1865 1865-12-02

# %%
bins = np.arange(10, 99, 5)
axM = dataframe.Date2.groupby(pd.cut(dataframe.Date2, bins)).agg([count_nonzero]).plot(kind='bar', 
                                                                legend=False)
axM.set_title("male riders")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8feadc22e5e3> in <module>()
#       1 bins = np.arange(10, 99, 5)
# ----> 2 axM = dataframe.Date2.groupby(pd.cut(dataframe.Date2, bins)).agg([count_nonzero]).plot(kind='bar',
#       3                                                                 legend=False)
#       4 axM.set_title("male riders")
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/tools/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest)
#     115     return _bins_to_cuts(x, bins, right=right, labels=labels,
#     116                          retbins=retbins, precision=precision,
# --> 117                          include_lowest=include_lowest)
#     118
#     119
#
# ...
